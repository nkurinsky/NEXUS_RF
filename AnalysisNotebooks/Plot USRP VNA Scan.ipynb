# %%
import sys, os, glob, h5py
import time, datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

## Load the modules
sys.path.insert(1, "/home/nexus-admin/NEXUS_RF/BackendTools")
import PyMKID_USRP_functions as PUf
import TimestreamHelperFunctions as Thf

# %%
# %matplotlib notebook

# %%
# datapath = '/data/USRP_VNA_Sweeps'
# datapath = '/data/USRP_Noise_Scans'
datapath = '/data/USRP_Laser_TempScan_Data'
series   = "20230216_040445"

# %%
sum_file, dly_file, vna_file, tone_files = Thf.GetFiles(series, 
                                                        base_path=datapath,
                                                        sep_noise_laser=False,
                                                        verbose=True)
# Out:
# Line Delay file:  USRP_Delay_20230216_040445.h5
# VNA scan file:    USRP_VNA_20230216_040445.h5
# Noise ts files:   ['USRP_Noise_20230216_040445_delta-5.h5']
# Laser ts files:   []
# Summary file:	 noise_averages_20230216_040445.h5

# %%
PUf.vna_file_fit(vna_file,[4.241983],show=True,save=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Fr from fit  [GHz]: 4.241929176217933
# Fr min curve [GHz]: 4.241928673933697
# <img src="data:image/png;base64,..." width="640">
# (array([4.24192918]),
#  array([139590.76642386]),
#  685668.32390987,
#  (0.011641970437978764+0.007867060880878381j),
#  -0.06039126077085619,
#  (9.895380300193164+0.6464683869773122j),
#  array([686920.57877336]))
